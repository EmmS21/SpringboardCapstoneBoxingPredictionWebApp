# %%
pip install Naked
# Out:
# Collecting Naked
#   Downloading https://files.pythonhosted.org/packages/02/36/b8107b51adca73402ec1860d88f41d958e275e60eea6eeaa9c39ddb89a40/Naked-0.1.31-py2.py3-none-any.whl (590kB)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from Naked) (5.1.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from Naked) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->Naked) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->Naked) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->Naked) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->Naked) (2019.9.11)
# Installing collected packages: Naked
# Successfully installed Naked-0.1.31
# Note: you may need to restart the kernel to use updated packages.

# %%
from Naked.toolshed.shell import muterun_js
import pandas as pd
success = muterun_js('index.js')
if success.exitcode == 0:
    print('Ran successfully')
else:
    print('Index.js did not produce any output')
# Out:
# Ran successfully

# %%
a = pd.read_json('C:\\Users\\User\\Documents\\testing.json',orient='columns')
def unpack_json(col_name):
    return a[col_name].apply(pd.Series)
a = unpack_json(str('boxers'))
a[['draw','loss','win']] = unpack_json(str('record'))
a[['country','region','town']] = unpack_json(str('residence'))
a[['countryid','countryName']] = unpack_json(str('country'))
a[['cityId','cityName']] = unpack_json(str('town'))
# a = unpack_json(str('residence'))
a.drop(['record','residence','country','region','town','cityId'],axis=1,inplace=True)
a = a.set_index(['id','name']).reset_index()
# a.to_csv('C:\\Users\\User\\Documents\\testingclean.csv')

# %%
a['division'] = 'heavyweight'

# %%
a
# Out:
#         id                  name   age  hasBoutScheduled  \
# 0   489762          Andy Ruiz Jr  30.0              True
# 1   468841        Deontay Wilder  34.0              True
# 2   659461        Anthony Joshua  30.0              True
# 3   659772        Oleksandr Usyk  32.0             False
# 4   479205            Tyson Fury  31.0             False
# 5   318081    Alexander Povetkin  40.0              True
# 6   569964         Dillian Whyte  31.0             False
# 7   528949            Luis Ortiz  40.0              True
# 8   498837        Jarrell Miller  31.0             False
# 9   511850          Kubrat Pulev  38.0              True
# 10  381739        Dereck Chisora  35.0             False
# 11  512994         Adam Kownacki  30.0             False
# 12  613846         Joseph Parker  27.0             False
# 13  813758         Filip Hrgovic  27.0              True
# 14  629462     Dominic Breazeale  34.0             False
# 15  503964           Oscar Rivas  32.0             False
# 16  475159      Christian Hammer  32.0             False
# 17  621653     Gerald Washington  37.0             False
# 18  631078        Charles Martin  33.0             False
# 19  811429             Joe Joyce  34.0             False
# 20  768670        Evgeny Romanov  34.0             False
# 21  640268        Michael Hunter  31.0              True
# 22  643611           Hughie Fury  25.0              True
# 23  280342            Marco Huck  34.0             False
# 24  804221            Efe Ajagba  25.0             False
# 25  483755           David Price  36.0             False
# 26  355273          Carlos Takam  38.0             False
# 27  787430         Daniel Dubois  22.0             False
# 28  575332          Agit Kabayel  27.0             False
# 29  238766       Johann Duhaupas  38.0             False
# 30  733157            Simon Kean  30.0              True
# 31  741417           Petar Milas  24.0             False
# 32  473857         Artur Szpilka  30.0             False
# 33  630710           David Allen  27.0             False
# 34  451505       Robert Helenius  35.0             False
# 35  387871           Eric Molina  37.0              True
# 36  681602  Martin Bakole Ilunga   NaN             False
# 37  489046          Lucas Browne  40.0              True
# 38  529630       Bryant Jennings  35.0             False
# 39  324806      Bermane Stiverne  41.0             False
# 40  212248         Chris Arreola  38.0             False
# 41  545749           Erkan Teper  37.0             False
# 42  795843             Tony Yoka  27.0             False
# 43  703923         Sergey Kuzmin  32.0              True
# 44  734408       Lukasz Rozanski  33.0             False
# 45  775950    Ali Eren Demirezen  29.0             False
# 46  309799          Mariusz Wach  39.0             False
# 47  601830         Mario Heredia  26.0              True
# 48  327656            Joey Abell  38.0             False
# 49   32364          Samuel Peter  39.0              True
#
#                                     last6  points  rating    stance  draw  \
# 0         [win, loss, win, win, win, win]     754     100  orthodox     0
# 1         [win, win, win, win, draw, win]     622     100  orthodox     1
# 2         [win, win, win, win, win, loss]     603     100  orthodox     0
# 3          [win, win, win, win, win, win]     580     100  southpaw     0
# 4         [win, win, win, draw, win, win]     549     100  orthodox     1
# 5         [win, win, win, win, loss, win]     483     100  orthodox     0
# 6          [win, win, win, win, win, win]     420     100  orthodox     0
# 7         [win, win, loss, win, win, win]     363     100  southpaw     0
# 8          [win, win, win, win, win, win]     359     100  orthodox     1
# 9          [win, win, win, win, win, win]     339     100  orthodox     0
# 10        [win, win, loss, win, win, win]     268      90  orthodox     0
# 11         [win, win, win, win, win, win]     247      90  orthodox     0
# 12       [win, win, loss, loss, win, win]     226      90  orthodox     0
# 13         [win, win, win, win, win, win]     177      80  orthodox     0
# 14       [win, loss, win, win, win, loss]     169      80  orthodox     0
# 15        [win, win, win, win, win, loss]     151      80  orthodox     0
# 16       [win, win, loss, win, win, loss]     143      80  orthodox     0
# 17      [win, loss, loss, win, loss, win]     135      80  orthodox     1
# 18       [loss, win, win, loss, win, win]     125      80  southpaw     1
# 19         [win, win, win, win, win, win]     124      80  orthodox     0
# 20         [win, win, win, win, win, win]     122      80  orthodox     0
# 21         [win, win, win, win, win, win]     121      70  orthodox     0
# 22      [loss, win, loss, win, win, loss]     114      70  orthodox     0
# 23   [win, win, loss, loss, win, unknown]      97      70  orthodox     1
# 24         [win, win, win, win, win, win]      91      70  orthodox     0
# 25      [loss, loss, win, win, win, loss]      90      70  orthodox     0
# 26       [win, win, loss, loss, win, win]      89      70  orthodox     1
# 27         [win, win, win, win, win, win]      88      70  orthodox     0
# 28         [win, win, win, win, win, win]      74      60  orthodox     0
# 29       [loss, win, win, win, loss, win]      74      60  orthodox     0
# 30        [win, win, win, loss, win, win]      72      60  orthodox     0
# 31         [win, win, win, win, win, win]      71      60  orthodox     0
# 32      [loss, loss, win, win, loss, win]      67      60  southpaw     0
# 33       [loss, win, win, win, win, loss]      63      60  orthodox     2
# 34       [win, loss, win, win, win, loss]      59      60  orthodox     0
# 35       [win, win, loss, win, loss, win]      59      60  orthodox     0
# 36        [win, loss, win, win, win, win]      58      60               0
# 37       [win, loss, win, win, win, loss]      55      60  orthodox     0
# 38       [win, win, win, win, loss, loss]      54      60  orthodox     0
# 39      [win, win, loss, win, loss, loss]      52      60  orthodox     1
# 40  [draw, unknown, loss, win, win, loss]      50      60  orthodox     1
# 41       [loss, win, win, win, loss, win]      47      60  orthodox     0
# 42         [win, win, win, win, win, win]      46      60  orthodox     0
# 43    [unknown, win, win, win, win, loss]      45      60  orthodox     0
# 44         [win, win, win, win, win, win]      45      60               0
# 45        [win, win, win, win, win, loss]      44      60  orthodox     0
# 46      [win, loss, loss, loss, win, win]      39      50  orthodox     0
# 47      [win, loss, win, draw, win, loss]      36      50  orthodox     1
# 48       [loss, win, win, win, loss, win]      36      50  southpaw     0
# 49      [win, loss, win, loss, win, loss]      35      50  orthodox     0
#
#     loss  win countryid     countryName         cityName     division
# 0      1   33        US             USA         Imperial  heavyweight
# 1      0   41        US             USA       Tuscaloosa  heavyweight
# 2      1   22        UK  United Kingdom          Watford  heavyweight
# 3      0   17        UA         Ukraine             None  heavyweight
# 4      0   29        UK  United Kingdom         Wilmslow  heavyweight
# 5      2   35        RU          Russia             None  heavyweight
# 6      1   26        UK  United Kingdom          Brixton  heavyweight
# 7      1   31        US             USA            Miami  heavyweight
# 8      0   23        US             USA         Brooklyn  heavyweight
# 9      1   27        BG        Bulgaria             None  heavyweight
# 10     9   32        UK  United Kingdom         Finchley  heavyweight
# 11     0   20        US             USA         Brooklyn  heavyweight
# 12     2   26        NZ     New Zealand             None  heavyweight
# 13     0    9        HR         Croatia             None  heavyweight
# 14     2   20        US             USA         Eastvale  heavyweight
# 15     1   26        CA          Canada         Montreal  heavyweight
# 16     6   24        DE         Germany             None  heavyweight
# 17     3   20        US             USA          Vallejo  heavyweight
# 18     2   27        US             USA           Carson  heavyweight
# 19     0   10        UK  United Kingdom           Putney  heavyweight
# 20     0   14        RU          Russia             None  heavyweight
# 21     1   18        US             USA        Las Vegas  heavyweight
# 22     3   23        UK  United Kingdom       Manchester  heavyweight
# 23     5   41        DE         Germany             None  heavyweight
# 24     0   11        US             USA         Stafford  heavyweight
# 25     7   25        UK  United Kingdom        Liverpool  heavyweight
# 26     5   37        US             USA        Henderson  heavyweight
# 27     0   13        UK  United Kingdom        Greenwich  heavyweight
# 28     0   19        DE         Germany           Bochum  heavyweight
# 29     5   38        FR          France        Abbeville  heavyweight
# 30     1   17        CA          Canada  Trois-Rivi̬res  heavyweight
# 31     0   15        HR         Croatia             None  heavyweight
# 32     4   23        PL          Poland             None  heavyweight
# 33     5   17        UK  United Kingdom      Conisbrough  heavyweight
# 34     3   28        FI         Finland             None  heavyweight
# 35     5   27        US             USA          Weslaco  heavyweight
# 36     1   15        UK  United Kingdom          Airdrie  heavyweight
# 37     2   28        AU       Australia           Sydney  heavyweight
# 38     4   24        US             USA     Philadelphia  heavyweight
# 39     4   25        US             USA        Las Vegas  heavyweight
# 40     6   38        US             USA        Escondido  heavyweight
# 41     3   20        DE         Germany            Ahlen  heavyweight
# 42     0    7        FR          France            Paris  heavyweight
# 43     1   15        RU          Russia             None  heavyweight
# 44     0   11        PL          Poland             None  heavyweight
# 45     1   11        DE         Germany             None  heavyweight
# 46     5   35        PL          Poland             None  heavyweight
# 47     7   16        MX          Mexico             None  heavyweight
# 48    10   35        US             USA      Coon Rapids  heavyweight
# 49     8   38        US             USA        Las Vegas  heavyweight

# %%
a.to_csv('C:\\Users\\User\\Documents\\testingclean.csv')

# %%
b = pd.read_json('C:\\Users\\User\\Documents\\kesting.json',orient='columns')

# %%
b.ix[:,0].apply(pd.Series)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#             0 1        2 3 4                   5     6                    7  \
# 0   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 1   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 2   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 3   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 4   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 5   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 6   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 7   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 8   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 9   issued by    expires      firstFighterWeight  date  secondFighterWeight
# 10  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 11  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 12  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 13  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 14  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 15  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 16  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 17  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 18  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 19  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 20  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 21  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 22  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 23  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 24  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 25  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 26  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 27  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 28  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 29  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 30  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 31  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 32  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 33  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 34  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 35  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 36  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 37  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 38  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 39  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 40  issued by    expires      firstFighterWeight  date  secondFighterWeight
# 41  issued by    expires      firstFighterWeight  date  secondFighterWeight
#
#            8         9                   10     11          12     13      14  \
# 0   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 1   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 2   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 3   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 4   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 5   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 6   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 7   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 8   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 9   location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 10  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 11  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 12  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 13  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 14  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 15  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 16  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 17  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 18  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 19  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 20  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 21  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 22  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 23  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 24  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 25  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 26  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 27  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 28  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 29  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 30  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 31  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 32  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 33  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 34  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 35  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 36  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 37  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 38  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 39  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 40  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
# 41  location  opponent  secondFighterWeight  w-l-d  firstLast6  links  result
#
#    15      16 17 18
# 0      rounds
# 1      rounds
# 2      rounds
# 3      rounds
# 4      rounds
# 5      rounds
# 6      rounds
# 7      rounds
# 8      rounds
# 9      rounds
# 10     rounds
# 11     rounds
# 12     rounds
# 13     rounds
# 14     rounds
# 15     rounds
# 16     rounds
# 17     rounds
# 18     rounds
# 19     rounds
# 20     rounds
# 21     rounds
# 22     rounds
# 23     rounds
# 24     rounds
# 25     rounds
# 26     rounds
# 27     rounds
# 28     rounds
# 29     rounds
# 30     rounds
# 31     rounds
# 32     rounds
# 33     rounds
# 34     rounds
# 35     rounds
# 36     rounds
# 37     rounds
# 38     rounds
# 39     rounds
# 40     rounds
# 41     rounds
